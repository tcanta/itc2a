# %% [markdown]
# # Cours: Modèle Entité-Association
#
#
# <iframe src=https://mozilla.github.io/pdf.js/web/viewer.html?file=https://raw.githubusercontent.com/tcanta/itc2a/master/cours/sql/er.pdf#zoom=page-fit&pagemode=none height=500 width=100% allowfullscreen></iframe>
